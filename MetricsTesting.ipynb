# %% [markdown]
# # External Imports

# %%
from pathlib import Path
import pickle
import gym
import random
import nle
from pprint import pprint
import numpy as np
import pandas as pd
import time
from datetime import datetime
import cProfile
from IPython import display
import os

# %% [markdown]
# # Internal Imports & Setup

# %%
from utils.terminal_stream import TerminalStream
from utils.nle_metrics import NetHackMetricsEnv

# %% [markdown]
# # Action Enumeration

# %%
env = gym.make('NetHackScore-v0')
obs = env.reset()

# %%
list(enumerate(env._actions))

# %%
pprint(obs)

# %%
list(enumerate(zip(obs[0]['blstats'],['x','y','str%','str','dx','co','in','wi','ch','score','hp','mxhp','depth','$','en','max_ene','ac','mlvl','xplvl','xp','time','hstate','carrycap','dngn#','lvl#'])))

# %% [markdown]
# # Example Testing

# %%
class RandomAgent():
    def __init__(self):
        self.actions = [1, 2, 3, 4]
    
    def act(self):
        return random.choice(self.actions)

# %%
agent = RandomAgent()
env = NetHackMetricsEnv('nh-ting')

# %%
for episode in range(5):
    env.start(f'rng-v{episode}')
    for i in range(100000):
        obs, reward, done, info = env.step(agent.act())
        if done:
            break
    env.finish()

# %%
env.write_report()
