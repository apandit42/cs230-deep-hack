# %%
"""
Import Statements: From PyTorch RL Tutorial
Unchanged code from Milestone
"""
import gym
import math
import random
import numpy as np
from itertools import count
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import nle
from collections import namedtuple, deque

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# env = NLEMetricsEnv(save_dir)
env = gym.make('NetHackChallenge-v0', savedir=None)

# %%
"""
This model stores each individual experience replay.
"""
class Experience():
    def __init__(self, state, action, next_state, reward):
        self.state - state
        self.action = action
        self.next_state = next_state
        self.reward = reward

# %%
StateTransition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

# %%
"""
This model stores replays of memories as a whole. It also holds the full set, and manages removing old memories.
"""
class ReplayMemory():
    def __init__(self, max_memory):
        self.memory = []
        self.max_memory = max_memory
    
    def push(self, newExp):
        if len(self.memory) >= self.max_memory:
            self.memory.pop(0)
        self.memory.append(newExp)
    
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

# %%
"""
DQN implementation, with convolutional layers, max pooling implemented.
"""
class DQNetwork(nn.Module):
    def __init__(self):
        super(DQNetwork, self).__init__()
        self.joe = nn.Sequential(
            nn.Conv2d(4, 16, kernel_size=3, padding='same'),
            nn.BatchNorm2d(16),
            nn.ReLU(), # 21 * 79 * 16
            nn.MaxPool2d(3, padding=(0,1)), # 7 * 27 * 16
            nn.Conv2d(16, 64, kernel_size=3, padding='same'),# 7 * 27 * 64
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(3, padding=(1,0)), # 3 * 9 * 64
            nn.Flatten(),
            nn.Linear(3*9*64, 3*64),
            nn.ReLU(),
            nn.Linear(3*64, 113),
        )
        
    def forward(self, x):
        logits = self.joe(x.float())
        return logits

# %%
BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10
steps_done = 0
episode_durations = []
# n_actions = env.action_space_size
n_actions = env.action_space.n
# All of the batches

# %%
policy_net = DQNetwork().to(device)
target_net = DQNetwork().to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(policy_net.parameters())
memory = ReplayMemory(10000)

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)

# %%
def optimize_model(iter_num):
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = StateTransition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1)[0].
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))
    if iter_num % 1000 == 0:
        print('Iteration number ' + str(iter_num) + ' loss: ' + str(loss.item()))
        env.render()
    
    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
def concat_state(state):
    state = np.stack((state['glyphs'], state['chars'], state['colors'], state['specials']))
    state = torch.tensor(np.expand_dims(state, axis=0), device=device)
    return state

# EPISODES
num_episodes = 10
for i_episode in range(num_episodes):
    print('Episode Number: ' + str(i_episode))
    # Initialize the environment and state
    # obs = env.reset(new_episode_name)
    obs = env.reset()
    state = concat_state(obs)
    for t in count():
        # Select and perform an action
        action = select_action(state)
        obs, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)
        
        # Keep track of current state and previous states 
        last_state = state
        state = concat_state(obs)

        # Store the transition in memory
        memory.push(StateTransition(last_state, action, state, reward))

        # Perform one step of the optimization (on the policy network)
        optimize_model(t)
        if done:
            episode_durations.append(t + 1)
            break
    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
print('Complete')
# no env close
env.close()
plt.ioff()
plt.show()
# Out:
# Episode Number: 0
# Iteration number 1000 loss: 0.8590710163116455
#
#                                          Comestibles
#                                          b - 5 uncursed food rations
#                                          d - 2 uncursed eggs
#                                          e - an uncursed slime mold
#                                          f - an uncursed melon
#                                          (end)
#                                                                  |..........|
#                                                                  |......<...|
#                                                                  -|----------
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:1
# Dlvl:1 $:534 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 2000 loss: 0.664383053779602
#
# The little dog picks up an uncursed apple.  $ - a gold piece.--More--
#
#                                                                  ------------
#                                                                  |.....@d...|
#                                                                  +..........|
#                                                                  |...%......|
#                                                                  |..........|
#                                                                  |......<...|
#                                                                  -|----------
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:2
# Dlvl:1 $:535 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 3000 loss: 0.29890573024749756
#
# Search for: ýmmmCCCCý+'''000XXXXTCCCCCC7BBBSSSSqqqqqDDCC@@@GýBB''0Oiiiiii
#                                                                          ý'ýB///
# 4g                            a - Coins
#                               b - Weapons
#                               c - Armor
#                               d - Comestibles
#                               e - Scrolls
#                               f - Potions
#                               g - Tools
#
#                               B - Items known to be Blessed
#                               U - Items known to be Uncursed
#                               (end)
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:2
# Dlvl:1 $:535 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 4000 loss: 0.19947686791419983
#
# Please move the cursor to an unknown object.--More--
#
# 4g                                                               ------------
#                                                                  |.......@..|
#                                                                  +.......%..|
#                                                                  |...%..d...|
#                                                                  |..........|
#                                                                  |......<...|
#                                                                  -|----------
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:2
# Dlvl:1 $:535 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 5000 loss: 0.5153275728225708
#
# You don't have that object.--More--
#
#                                                                  ------------
#                                                                  |..........|
#                                                                  +.......%..|
#                                                                  |...%...d..|
#                                                                  |..........|
#                                                                  |......<@..|
#                                                                  -|----------
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:2
# Dlvl:1 $:535 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 6000 loss: 0.3708392083644867
#
# You don't have that object.--More--
#
#                                                                  ------------
#                                                                  |.........@|
#                                                                  +.......%d.|
#                                                                  |...%......|
#                                                                  |..........|
#                                                                  |......<...|
#                                                                  -|----------
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:2
# Dlvl:1 $:535 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 7000 loss: 0.22328121960163116
#
# You don't have that object.--More--
#
#                                                                  ------------
#                                                                  |.......@.%|
#                                                                  +........d.|
#                                                                  |...%......|
#                                                                  |..........|
#                                                                  |......<...|
#                                                                  -|----------
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:2
# Dlvl:1 $:535 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 8000 loss: 0.2943214774131775
#
#                                    View discoveries for which sort of objects?
#
#                                    a - scrolls
#                                    b - potions
#                                    (end)
#                                                                  |...%.....d|
#                                                                  |........%.|
#                                                                  |......<...|
#                                                                  -|----------
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:2
# Dlvl:1 $:535 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 9000 loss: 0.22003591060638428
#
# Really quit? [yn] (n)
#
#                                                                  ------------
#                                                                  |..........|
#                                                                  +..........|
#                                                                  |...%..@...|
#                                                                  |.....d....|
#                                                                  |......<.%.|
#                                                                  -|----------
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Rambler              St:12 Dx:9 Co:17 In:12 Wi:11 Ch:14 Neutral S:2
# Dlvl:1 $:535 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Episode Number: 1
# Iteration number 0 loss: 3.1144003868103027
#
# You don't have anything else to wear.
#
#
#
#
#
#
#
#
#
#
#  ------
#  |....|
#  |.@..+
#  |d...|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:0
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 1000 loss: 0.6793708205223083
#
#
#
#                                          A - Auto-select every item
#
#                                          a - All types
#                                          b - Coins
#                                          c - Weapons
#                                          d - Armor
#                                          e - Comestibles
#                                          f - Scrolls
#                                          g - Potions
#  ------                                  h - Tools
#  |.@..|
#  |.<..+                                  U - Items known to be Uncursed
#  |d...|                                  (end)
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:0
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 2000 loss: 0.17148150503635406
#
#                                          Discoveries
#
#                                          Scrolls
#                                            scroll of magic mapping (NR 9)
#                                          Potions
#                                            potion of extra healing (orange)
#                                          --More--
#
#
#
#
#  ------
#  |@d..|
#  |.<..+
#  |....|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:0
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 3000 loss: 0.121385358273983
#
# # ###wwwgggýýUUý```IIIIVýýýýS7II,ýýrrrCb2ý     ýýcýý
#                                                     000
#
#
#
#
#
#
#
#
#
#  ------
#  |@...|
#  |d<..+
#  |....|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:0
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 4000 loss: 0.371803879737854
#
# You don't have that object.--More--
#
#
#
#
#
#
#
#
#
#
#  ------
#  |@...|
#  |d<..+
#  |....|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:0
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 5000 loss: 0.11036334186792374
#
# You don't have that object.--More--
#
#
#
#
#
#
#
#
#
#
#  ------
#  |...@|
#  |.<..+
#  |...d|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:0
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 6000 loss: 0.14272314310073853
#
# You don't have that object.--More--
#
#
#
#
#
#
#
#
#
#
#  ------
#  |...@|
#  |.<..+
#  |...d|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:0
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/0
# Iteration number 7000 loss: 0.31326717138290405
#
# You write in the dust with 29 +2 darts (at the ready).--More--
#
#
#
#
#
#
#
#
#
#
#  ------
#  |..d@|
#  |.<..+
#  |....|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:4
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/1 Satiated Conf
# Iteration number 8000 loss: 0.12030142545700073
#
#                                          Tools
#                                          l - an expensive camera (0:90)
# :"""""ýHHffýýW***"""XXCCCfff             m - an uncursed credit card
#                                          (end)
#
#
#
#
#
#
#
#  ------
#  |..d@|
#  |.<..+
#  |....|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:4
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/1 Satiated Conf
# Iteration number 9000 loss: 0.3484373688697815
#
# You don't have that object.--More--
#
#
#
#
#
#
#
#
#
#
#  ------
#  |...@|
#  |.<..+
#  |....|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:4
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/1 Satiated
# Iteration number 10000 loss: 0.26196587085723877
#
# Unix NetHack Version 3.6.6-0 post-release - last build Fri Nov 26 17:29:27
#                                                                           2021.-
# -More--
#
#
#
#
#
#
#
#
#  ------
#  |....|
#  |.<..+
#  |....|
#  |.....
#  |...d|
#  |...@|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:4
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/1 Satiated
# Iteration number 11000 loss: 0.27490341663360596
#
# You don't have that object.--More--
#
#
#
#
#
#
#
#
#
#
#  ------
#  |....|
#  |.<.@+
#  |....|
#  |.....
#  |....|
#  |....|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:4
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/1 Satiated
# Iteration number 12000 loss: 0.1597989797592163
#
#                                        Coins
#                                        $ - 181 gold pieces
#                                        Weapons
#                                        a - 29 +2 darts (at the ready)
#                                        Armor
#                                        k - an uncursed +0 Hawaiian shirt
#                                        Comestibles
#                                        b - 2 uncursed fortune cookies
#                                        c - an uncursed egg
#                                        f - 3 uncursed food rations
#                                        g - 2 uncursed cream pies
#  ------                                h - an uncursed tin of newt meat
#  |....|                                Scrolls
#  |.@%.+                                j - 4 uncursed scrolls of magic mapping
#  |..d.|                                Potions
#  |.....                                i - 2 uncursed potions of extra healing
#  |....|                                Tools
#  |....|                                l - an expensive camera (0:90)
#  ------                                m - an uncursed credit card
#                                        (end)
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:4
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/1 Satiated
# Iteration number 13000 loss: 0.24143429100513458
#
#  Current skills:
#
#  Fighting Skills
#    bare handed combat [Unskilled]
#    two weapon combat  [Unskilled]
#    riding             [Unskilled]
#  Weapon Skills
#    dagger             [Unskilled]
#    knife              [Unskilled]
#    axe                [Unskilled]
#    pick-axe           [Unskilled]
#    short sword        [Unskilled]
#    broadsword         [Unskilled]
#    long sword         [Unskilled]
#    two-handed sword   [Unskilled]
#    scimitar           [Unskilled]
#    saber              [Unskilled]
#    mace               [Unskilled]
#    morning star       [Unskilled]
#    flail              [Unskilled]
#    hammer             [Unskilled]
#    quarterstaff       [Unskilled]
#    polearms           [Unskilled]
#  (1 of 2)
# Iteration number 14000 loss: 0.11951255798339844
#
# Search for: ýgýý@LLLL:::ggggg+++GsýýPmmlý//ýmmm55i;;;;;;;,,CCcVý2
#                                                                  ýaa> ;'''h
#                                          Weapons
#                                          a + 29 +2 darts (at the ready)
#                                          (end)
#
#
#
#
#
#
#  ------
#  |....|
#  |.<..+
#  |....|
#  |%....
#  |.d..|
#  |..@.|
#  ------
#
#
#
# Agent the Rambler              St:18 Dx:12 Co:16 In:11 Wi:6 Ch:12 Neutral S:4
# Dlvl:1 $:181 HP:10(10) Pw:2(2) AC:10 Xp:1/1 Satiated
# Iteration number 15000 loss: 0.19489958882331848
#
# No count allowed with this command.--More--
# ...
# Iteration number 18000 loss: 0.019337540492415428
#
# You don't have that object.--More--
#
#                            ----------       -------------
#                            |........|       ............|
#                            +.@...{..|      ..............
#                            |.d.......#  # |.............|
#                            -.-----$--    #..............|
#                             ###   #      #|..............
#                               ##  #      # ---- ---------
#                                ## ###    #
#                                 ### #   ##
#                                  -.-.- ##
#                                  |...| # #
#                                  |<..| #
#                                  |...|##
#                                  |...|#
#                                  |....#
#                                  |..%|
#                                  -----
#
#
#
# Agent the Plunderer            St:18/03 Dx:15 Co:18 In:7 Wi:8 Ch:7 Chaotic S:2
# Dlvl:1 $:2 HP:15(15) Pw:2(2) AC:10 Xp:1/0
# Iteration number 19000 loss: 0.0829852968454361
#
# You have no ammunition readied.--More--
#
#                            ----------       -------------
#                            |.......@|       ............|
#                            +.....{..|      ..............
#                            |.$.......#  # |.............|
#                            -.-----.--    #..............|
#                             ###   #      #|..............
#                               ##  #      # ---- ---------
#                                ## ###    #
#                                 ### #   ##
#                                  -.-.- ##
#                                  |...| # #
#                                  |<..| #
#                                  |...|##
#                                  |...|#
#                                  |....#
#                                  |..%|
#                                  -----
#
#
#
# Agent the Plunderer            St:18/03 Dx:15 Co:18 In:7 Wi:8 Ch:7 Chaotic S:2
# Dlvl:1 $:2 HP:15(15) Pw:2(2) AC:10 Xp:1/0
# Iteration number 20000 loss: 0.028592629358172417
#
#                                    View discoveries for which sort of objects?
#
#                            ------- a - weapons
#                            |...... b - armor
#                            +d....{ c - potions
#                            |$$.... d - tools
#                            -@----- (end)
#                             ###   #      #|..............
#                               ##  #      # ---- ---------
#                                ## ###    #
#                                 ### #   ##
#                                  -.-.- ##
#                                  |...| # #
#                                  |<..| #
#                                  |...|##
#                                  |...|#
#                                  |....#
#                                  |..%|
#                                  -----
#
#
#
# Agent the Plunderer            St:18/03 Dx:15 Co:18 In:7 Wi:8 Ch:7 Chaotic S:2
# Dlvl:1 $:2 HP:15(15) Pw:2(2) AC:10 Xp:1/0
# Iteration number 21000 loss: 0.033613912761211395
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Discoveries
#  --More--
# Iteration number 22000 loss: 0.10220637917518616
#
# Really quit? [yn] (n)
#
# ý@@                        ----------       -------------
#                            |........|       ............|
#                            +.....$..|   #  ..............
#                            |$.......d#_@# |.............|
#                            -.-----.--    #..............|
#                             ###   #      #|..............
#                               ##  #      # ---- ---------
#                                ## ###    #
#                                 ### #   ##
#                                  -.-.- ##
#                                  |...| # #
#                                  |<..| #
#                                  |...|##
#                                  |...|#
#                                  |....#
#                                  |..%|
#                                  -----
#
#
#
# Agent the Plunderer            St:18/03 Dx:15 Co:18 In:7 Wi:8 Ch:7 Chaotic S:5
# Dlvl:1 $:5 HP:15(15) Pw:2(2) AC:10 Xp:1/0
# Iteration number 23000 loss: 0.035415034741163254
#
# Search for: :,RRRRRNNN^^^^QQ+fuuRRYYkký555555tttt77ýAAIIIss5;ý^^^^^I5bppp
#                                                                          Vý
#                            ----------   / - something on the map
#                            |........|   i - something you're carrying
#                            +.....$..|   ? - something else (by symbol or name)
#                            |$.......d#_
#                            -.-----.--   m - nearby monsters
#                             ###   #     M - all monsters shown on map
#                               ##  #     o - nearby objects
#                                ## ###   O - all objects shown on map
#                                 ### #   (end)
#                                  -.-.- ##
#                                  |...| # #
#                                  |<..| #
#                                  |...|##
#                                  |...|#
#                                  |....#
#                                  |..%|
#                                  -----
#
#
#
# Agent the Plunderer            St:18/03 Dx:15 Co:18 In:7 Wi:8 Ch:7 Chaotic S:5
# Dlvl:1 $:5 HP:15(15) Pw:2(2) AC:10 Xp:1/0
# Episode Number: 4
# Iteration number 0 loss: 0.0913579985499382
#
#                                          Drop what type of items?
#
#                                          A - Auto-select every item
#
#                                          a - All types
#                                          b - Weapons
#                                          c - Armor
#                                          d - Comestibles
#                                          e - Spellbooks
#                                          f - Potions
#                                          g - Tools
#
#                                          B - Items known to be Blessed
#                                          U - Items known to be Uncursed
#                                          (end)
#                                                                       |....|
#                                                                       |..f@|
#                                                                       |....|
#                                                                       |....|
#                                                                       |....|
#                                                                       ------
#
# Agent the Aspirant             St:13 Dx:14 Co:16 In:8 Wi:14 Ch:10 Chaotic S:0
# Dlvl:1 $:0 HP:13(13) Pw:9(9) AC:7 Xp:1/0
# Iteration number 1000 loss: 0.019035708159208298
#
#                                         Weapons
#                                         a - a blessed +1 mace (weapon in hand)
#                                         Armor
#                                         b - a blessed +0 robe (being worn)
#                                         c - a +0 small shield (being worn)
#                                         (end)
#
#
#
#
#
#
#
#                                                                       --.-|-
#                                                                       |@f..|
#                                                                       |....|
#                                                                       |...<|
#                                                                       |....|
#                                                                       |....|
#                                                                       |....|
#                                                                       ------
#
# Agent the Aspirant             St:13 Dx:14 Co:16 In:8 Wi:14 Ch:10 Chaotic S:0
# Dlvl:1 $:0 HP:13(13) Pw:9(9) AC:7 Xp:1/0

# %%
max(episode_durations)
# Out:
# 106754

# %%
rewards = [x.reward for x in memory.memory]
max(rewards)
# Out:
# tensor([0.], device='cuda:0')
